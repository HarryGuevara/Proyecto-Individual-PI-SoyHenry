# %%
import pandas as pd

# Cargar el dataset combinado
combined_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/combined_dataset.csv')

# Cargar los datasets individuales (suponiendo que también están en formato CSV)
movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\1191142523.py:4: DtypeWarning: Columns (2,4,8,9,10,14,15,16,17,18,37,38,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/combined_dataset.csv')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\1191142523.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\1191142523.py:8: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# %%
# Revisión de los primeros datos
print("Combined Dataset:")
print(combined_df.head())
# Out:
# Combined Dataset:
#    budget  id_film original_language  overview popularity release_date  \
# 0       0        0               104  Released        0.0   1900-01-01
# 1       0        0               104  Released        0.0   1900-01-01
# 2       0        0               104  Released        0.0   1900-01-01
# 3       0        0               104  Released        0.0   1900-01-01
# 4       0        0               104  Released        0.0   1900-01-01
#
#    revenue  runtime status tagline  ...           name_actor  order  \
# 0      0.0      0.0    NaN     NaN  ...          Hadley Eure   14.0
# 1      0.0      0.0    NaN     NaN  ...   Kadina de Elejalde   15.0
# 2      0.0      0.0    NaN     NaN  ...  Alessandra Benjamin   16.0
# 3      0.0      0.0    NaN     NaN  ...      Karen S. Gregan   17.0
# 4      0.0      0.0    NaN     NaN  ...      Brandon Jarrett   18.0
#
#    profile_path               credit_id.1         department gender.1  \
# 0           NaN  52fe424ec3a36847f8014099         Production      0.0
# 1           NaN  52fe424ec3a36847f801409f                Art      2.0
# 2           NaN  52fe424ec3a36847f80140a5                Art      2.0
# 3           NaN  52fe424ec3a36847f80140ab  Costume & Make-Up      2.0
# 4           NaN  570e345ec3a3684517000148             Camera      2.0
#
#     id_job                 job          name_job  \
# 0   7534.0             Casting  Gretchen Rennell
# 1   1049.0   Production Design     Charles Rosen
# 2   8867.0      Set Decoration      Marvin March
# 3    605.0      Costume Design    Michael Kaplan
# 4  55245.0  Still Photographer   John R. Shannon
#
#                      profile_path.1
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  /pgME9OWsN2y3UZw1OsXbqmN2fEx.jpg
# 4                               NaN
#
# [5 rows x 44 columns]

# %%
# Información de los DataFrames
print("\nCombined Dataset Info:")
print(combined_df.info())
# Out:
# Combined Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1603787 entries, 0 to 1603786
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   budget                           1603787 non-null  int64
#  1   id_film                          1603787 non-null  int64
#  2   original_language                1603776 non-null  object
#  3   overview                         1602833 non-null  object
#  4   popularity                       1603787 non-null  object
#  5   release_date                     1603787 non-null  object
#  6   revenue                          1603787 non-null  float64
#  7   runtime                          1603787 non-null  float64
#  8   status                           45455 non-null    object
#  9   tagline                          20439 non-null    object
#  10  title_film                       45536 non-null    object
#  11  vote_average                     1603787 non-null  float64
#  12  vote_count                       1603787 non-null  float64
#  13  collection_id                    1603787 non-null  float64
#  14  collection_name                  4393 non-null     object
#  15  collection_poster                3957 non-null     object
#  16  collection_backdrop              3269 non-null     object
#  17  company_names                    45536 non-null    object
#  18  company_ids                      45536 non-null    object
#  19  release_year                     1603787 non-null  int64
#  20  return                           1603787 non-null  float64
#  21  id_genres                        1603787 non-null  object
#  22  name_genres                      1603787 non-null  object
#  23  id_production_companies          1603787 non-null  object
#  24  name_production_companies        1603787 non-null  object
#  25  iso_639_1_spoken_languages       1603787 non-null  object
#  26  name_spoken_languages            1603787 non-null  object
#  27  iso_3166_1_production_countries  1603787 non-null  object
#  28  name_production_countries        1603787 non-null  object
#  29  cast_id                          1603786 non-null  float64
#  30  character                        1520375 non-null  object
#  31  credit_id                        1596612 non-null  object
#  32  gender                           1603786 non-null  float64
#  33  id_actor                         1603786 non-null  float64
#  34  name_actor                       1596612 non-null  object
#  35  order                            1603786 non-null  float64
#  36  profile_path                     1100982 non-null  object
#  37  credit_id.1                      1302090 non-null  object
#  38  department                       1302090 non-null  object
#  39  gender.1                         1302090 non-null  float64
#  40  id_job                           1603786 non-null  float64
#  41  job                              1302090 non-null  object
#  42  name_job                         1302090 non-null  object
#  43  profile_path.1                   264023 non-null   object
# dtypes: float64(12), int64(3), object(29)
# memory usage: 538.4+ MB
# None

# %%
# Estadísticas descriptivas
print("Combined Dataset Description:")
print(combined_df.describe(include='all'))
# Out:
# Combined Dataset Description:
#               budget       id_film  original_language  overview  popularity  \
# count   1.603787e+06  1.603787e+06          1603776.0   1602833   1603787.0
# unique           NaN           NaN               93.0     44307     43837.0
# top              NaN           NaN              104.0  Released         0.0
# freq             NaN           NaN           519416.0   1558248   1032258.0
# mean    1.199161e+05  3.075807e+03                NaN       NaN         NaN
# std     3.016956e+06  2.612497e+04                NaN       NaN         NaN
# min     0.000000e+00  0.000000e+00                NaN       NaN         NaN
# 25%     0.000000e+00  0.000000e+00                NaN       NaN         NaN
# 50%     0.000000e+00  0.000000e+00                NaN       NaN         NaN
# 75%     0.000000e+00  0.000000e+00                NaN       NaN         NaN
# max     3.800000e+08  4.691720e+05                NaN       NaN         NaN
#
#        release_date       revenue       runtime    status  \
# count       1603787  1.603787e+06  1.603787e+06     45455
# unique        17333           NaN           NaN         6
# top      1900-01-01           NaN           NaN  Released
# freq        1558339           NaN           NaN     45088
# mean            NaN  3.179526e+05  2.657430e+00       NaN
# std             NaN  1.098997e+07  1.687301e+01       NaN
# min             NaN  0.000000e+00  0.000000e+00       NaN
# 25%             NaN  0.000000e+00  0.000000e+00       NaN
# 50%             NaN  0.000000e+00  0.000000e+00       NaN
# 75%             NaN  0.000000e+00  0.000000e+00       NaN
# max             NaN  2.787965e+09  1.256000e+03       NaN
#
#                                                   tagline  ...    name_actor  \
# count                                               20439  ...       1596612
# unique                                              20283  ...        202747
# top     Which one is the first to return - memory or t...  ...  Bess Flowers
# freq                                                    9  ...           677
# mean                                                  NaN  ...           NaN
# std                                                   NaN  ...           NaN
# min                                                   NaN  ...           NaN
# 25%                                                   NaN  ...           NaN
# 50%                                                   NaN  ...           NaN
# 75%                                                   NaN  ...           NaN
# max                                                   NaN  ...           NaN
#
#                order                      profile_path  \
# count   1.603786e+06                           1100982
# unique           NaN                             77370
# top              NaN  /akbW8jJl8GSXFpixFaobMOqvNv4.jpg
# freq             NaN                               677
# mean    1.153621e+01                               NaN
# std     1.539870e+01                               NaN
# min     0.000000e+00                               NaN
# 25%     3.000000e+00                               NaN
# 50%     7.000000e+00                               NaN
# 75%     1.400000e+01                               NaN
# max     3.130000e+02                               NaN
#
#                      credit_id.1  department      gender.1        id_job  \
# count                    1302090     1302090  1.302090e+06  1.603786e+06
# unique                    463836          12           NaN           NaN
# top     52fe4ac89251416c750edd47  Production           NaN           NaN
# freq                           9      265833           NaN           NaN
# mean                         NaN         NaN  7.444531e-01  5.325074e+05
# std                          NaN         NaN  9.323737e-01  6.625621e+05
# min                          NaN         NaN  0.000000e+00  0.000000e+00
# 25%                          NaN         NaN  0.000000e+00  6.046000e+03
# 50%                          NaN         NaN  0.000000e+00  7.253300e+04
# 75%                          NaN         NaN  2.000000e+00  1.302176e+06
# max                          NaN         NaN  2.000000e+00  1.908001e+06
#
#              job        name_job                    profile_path.1
# count    1302090         1302090                            264023
# unique       456          157614                             13347
# top     Director  Cedric Gibbons  /w8tc9iVH87Iu1KKFDZ9B99NhnBc.jpg
# freq      141172             782                               782
# mean         NaN             NaN                               NaN
# std          NaN             NaN                               NaN
# min          NaN             NaN                               NaN
# 25%          NaN             NaN                               NaN
# 50%          NaN             NaN                               NaN
# 75%          NaN             NaN                               NaN
# max          NaN             NaN                               NaN
#
# [11 rows x 44 columns]

# %%
# Revisión de los primeros datos
print("\nMovie Dataset Cleaned:")
print(movie_df.head())
# Out:
# Movie Dataset Cleaned:
#      budget id_film original_language  \
# 0  30000000     862                en
# 1  65000000    8844                en
# 2         0   15602                en
# 3  16000000   31357                en
# 4         0   11862                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  1715539.0   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...   8.387519   1995-02-10
#
#        revenue  runtime    status  \
# 0  373554033.0     81.0  Released
# 1  262797249.0    104.0  Released
# 2          0.0    101.0  Released
# 3   81452156.0    127.0  Released
# 4   76578911.0    106.0  Released
#
#                                              tagline  ... release_year  \
# 0                                                NaN  ...         1995
# 1          Roll the dice and unleash the excitement!  ...         1995
# 2  Still Yelling. Still Fighting. Still Ready for...  ...         1995
# 3  Friends are the people who let you be yourself...  ...         1995
# 4  Just When His World Is Back To Normal... He's ...  ...         1995
#
#       return        id_genres                         name_genres  \
# 0  12.451801  [16, 35, 10751]   ['Animation', 'Comedy', 'Family']
# 1   4.043035  [12, 14, 10751]  ['Adventure', 'Fantasy', 'Family']
# 2   0.000000      [10749, 35]               ['Romance', 'Comedy']
# 3   5.090760  [35, 18, 10749]      ['Comedy', 'Drama', 'Romance']
# 4   0.000000             [35]                          ['Comedy']
#
#   id_production_companies                          name_production_companies  \
# 0                     [3]                        ['Pixar Animation Studios']
# 1      [559, 2550, 10201]  ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 2           [6194, 19464]                 ['Warner Bros.', 'Lancaster Gate']
# 3                   [306]         ['Twentieth Century Fox Film Corporation']
# 4            [5842, 9195]   ['Sandollar Productions', 'Touchstone Pictures']
#
#   iso_639_1_spoken_languages    name_spoken_languages  \
# 0                     ['en']              ['English']
# 1               ['en', 'fr']  ['English', 'Français']
# 2                     ['en']              ['English']
# 3                     ['en']              ['English']
# 4                     ['en']              ['English']
#
#   iso_3166_1_production_countries     name_production_countries
# 0                          ['US']  ['United States of America']
# 1                          ['US']  ['United States of America']
# 2                          ['US']  ['United States of America']
# 3                          ['US']  ['United States of America']
# 4                          ['US']  ['United States of America']
#
# [5 rows x 29 columns]

# %%
# Información de los DataFrames
print("\nMovie Dataset Cleaned Info:")
print(movie_df.info())
# Out:
# Movie Dataset Cleaned Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 29 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   budget                           45466 non-null  int64
#  1   id_film                          45466 non-null  object
#  2   original_language                45455 non-null  object
#  3   overview                         44512 non-null  object
#  4   popularity                       45466 non-null  object
#  5   release_date                     45466 non-null  object
#  6   revenue                          45466 non-null  float64
#  7   runtime                          45466 non-null  float64
#  8   status                           45379 non-null  object
#  9   tagline                          20412 non-null  object
#  10  title_film                       45460 non-null  object
#  11  vote_average                     45466 non-null  float64
#  12  vote_count                       45466 non-null  float64
#  13  collection_id                    45466 non-null  float64
#  14  collection_name                  4384 non-null   object
#  15  collection_poster                3948 non-null   object
#  16  collection_backdrop              3263 non-null   object
#  17  company_names                    45460 non-null  object
#  18  company_ids                      45460 non-null  object
#  19  release_year                     45466 non-null  int64
#  20  return                           45466 non-null  float64
#  21  id_genres                        45466 non-null  object
#  22  name_genres                      45466 non-null  object
#  23  id_production_companies          45466 non-null  object
#  24  name_production_companies        45466 non-null  object
#  25  iso_639_1_spoken_languages       45466 non-null  object
#  26  name_spoken_languages            45466 non-null  object
#  27  iso_3166_1_production_countries  45466 non-null  object
#  28  name_production_countries        45466 non-null  object
# dtypes: float64(6), int64(2), object(21)
# memory usage: 10.1+ MB
# None

# %%
# Estadísticas descriptivas
print("\nMovie Dataset Cleaned Description:")
print(movie_df.describe(include='all'))
# Out:
# Movie Dataset Cleaned Description:
#               budget id_film original_language            overview  \
# count   4.546600e+04   45466             45455               44512
# unique           NaN   45436                92               44307
# top              NaN  141971                en  No overview found.
# freq             NaN       3             32269                 133
# mean    4.224300e+06     NaN               NaN                 NaN
# std     1.742359e+07     NaN               NaN                 NaN
# min     0.000000e+00     NaN               NaN                 NaN
# 25%     0.000000e+00     NaN               NaN                 NaN
# 50%     0.000000e+00     NaN               NaN                 NaN
# 75%     0.000000e+00     NaN               NaN                 NaN
# max     3.800000e+08     NaN               NaN                 NaN
#
#         popularity release_date       revenue       runtime    status  \
# count      45466.0        45466  4.546600e+04  45466.000000     45379
# unique     44163.0        17333           NaN           NaN         6
# top            0.0   2008-01-01           NaN           NaN  Released
# freq          36.0          136           NaN           NaN     45014
# mean           NaN          NaN  1.120787e+07     93.583711       NaN
# std            NaN          NaN  6.432813e+07     38.956167       NaN
# min            NaN          NaN  0.000000e+00      0.000000       NaN
# 25%            NaN          NaN  0.000000e+00     85.000000       NaN
# 50%            NaN          NaN  0.000000e+00     95.000000       NaN
# 75%            NaN          NaN  0.000000e+00    107.000000       NaN
# max            NaN          NaN  2.787965e+09   1256.000000       NaN
#
#                        tagline  ...  release_year        return  id_genres  \
# count                    20412  ...  45466.000000  4.546600e+04      45466
# unique                   20283  ...           NaN           NaN       4069
# top     Based on a true story.  ...           NaN           NaN       [18]
# freq                         7  ...           NaN           NaN       5000
# mean                       NaN  ...   1991.699314  6.587362e+02        NaN
# std                        NaN  ...     24.376082  7.461933e+04        NaN
# min                        NaN  ...   1874.000000  0.000000e+00        NaN
# 25%                        NaN  ...   1978.000000  0.000000e+00        NaN
# 50%                        NaN  ...   2001.000000  0.000000e+00        NaN
# 75%                        NaN  ...   2010.000000  0.000000e+00        NaN
# max                        NaN  ...   2020.000000  1.239638e+07        NaN
#
#         name_genres id_production_companies name_production_companies  \
# count         45466                   45466                     45466
# unique         4069                   22707                     22672
# top       ['Drama']                      []                        []
# freq           5000                   11881                     11881
# mean            NaN                     NaN                       NaN
# std             NaN                     NaN                       NaN
# min             NaN                     NaN                       NaN
# 25%             NaN                     NaN                       NaN
# 50%             NaN                     NaN                       NaN
# 75%             NaN                     NaN                       NaN
# max             NaN                     NaN                       NaN
#
#        iso_639_1_spoken_languages name_spoken_languages  \
# count                       45466                 45466
# unique                       1931                  1843
# top                        ['en']           ['English']
# freq                        22395                 22395
# mean                          NaN                   NaN
# std                           NaN                   NaN
# min                           NaN                   NaN
# 25%                           NaN                   NaN
# 50%                           NaN                   NaN
# 75%                           NaN                   NaN
# max                           NaN                   NaN
#
#        iso_3166_1_production_countries     name_production_countries
# count                            45466                         45466
# unique                            2390                          2390
# top                             ['US']  ['United States of America']
# freq                             17851                         17851
# mean                               NaN                           NaN
# std                                NaN                           NaN
# min                                NaN                           NaN
# 25%                                NaN                           NaN
# 50%                                NaN                           NaN
# 75%                                NaN                           NaN
# max                                NaN                           NaN
#
# [11 rows x 29 columns]

# %%
# Revisión de los primeros datos
print("\nDF Unido:")
print(df_unido_df.head())
# Out:
# DF Unido:
#    id_film  cast_id                character                 credit_id  \
# 0      862       14            Woody (voice)  52fe4284c3a36847f8024f95
# 1     8844       15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 2    15602       16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 3    31357       17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 4    11862       18              Rex (voice)  52fe4284c3a36847f8024fa5
#
#    gender  id_actor     name_actor  order                      profile_path  \
# 0       2        31      Tom Hanks      0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1       2     12898      Tim Allen      1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2       2      7167    Don Rickles      2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3       2     12899     Jim Varney      3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4       2     12900  Wallace Shawn      4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg
#
#                 credit_id.1 department  gender.1  id_job         job  \
# 0  52fe4284c3a36847f8024f49  Directing       2.0    7879    Director
# 1  52fe4284c3a36847f8024f4f    Writing       2.0   12891  Screenplay
# 2  52fe4284c3a36847f8024f55    Writing       2.0       7  Screenplay
# 3  52fe4284c3a36847f8024f5b    Writing       2.0   12892  Screenplay
# 4  52fe4284c3a36847f8024f61    Writing       0.0   12893  Screenplay
#
#          name_job                    profile_path.1
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg

# %%
# Información de los DataFrames
print("\nDF Unido Info:")
print(df_unido_df.info())
# Out:
# DF Unido Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564892 entries, 0 to 564891
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_film         564892 non-null  int64
#  1   cast_id         564892 non-null  int64
#  2   character       536691 non-null  object
#  3   credit_id       562474 non-null  object
#  4   gender          564892 non-null  int64
#  5   id_actor        564892 non-null  int64
#  6   name_actor      562474 non-null  object
#  7   order           564892 non-null  int64
#  8   profile_path    388618 non-null  object
#  9   credit_id.1     464314 non-null  object
#  10  department      464314 non-null  object
#  11  gender.1        464314 non-null  float64
#  12  id_job          564892 non-null  int64
#  13  job             464314 non-null  object
#  14  name_job        464314 non-null  object
#  15  profile_path.1  95098 non-null   object
# dtypes: float64(1), int64(6), object(9)
# memory usage: 69.0+ MB
# None

# %%
# Estadísticas descriptivas
print("\nDF Unido Description:")
print(df_unido_df.describe(include='all'))
# Out:
# DF Unido Description:
#              id_film        cast_id character                 credit_id  \
# count   564892.00000  564892.000000    536691                    562474
# unique           NaN            NaN    319326                    562044
# top              NaN            NaN   Himself  52fe4ac89251416c750edd31
# freq             NaN            NaN     11437                         3
# mean      8722.27361      51.342657       NaN                       NaN
# std      43437.14812     172.661055       NaN                       NaN
# min          0.00000       0.000000       NaN                       NaN
# 25%          0.00000       6.000000       NaN                       NaN
# 50%          0.00000      13.000000       NaN                       NaN
# 75%          0.00000      27.000000       NaN                       NaN
# max     469172.00000    1119.000000       NaN                       NaN
#
#                gender      id_actor    name_actor          order  \
# count   564892.000000  5.648920e+05        562474  564892.000000
# unique            NaN           NaN        202747            NaN
# top               NaN           NaN  Bess Flowers            NaN
# freq              NaN           NaN           241            NaN
# mean         1.000586  4.478115e+05           NaN      11.794922
# std          0.895596  6.000447e+05           NaN      15.989719
# min          0.000000  0.000000e+00           NaN       0.000000
# 25%          0.000000  2.693075e+04           NaN       3.000000
# 50%          1.000000  9.651550e+04           NaN       7.000000
# 75%          2.000000  1.037884e+06           NaN      14.000000
# max          2.000000  1.908262e+06           NaN     313.000000
#
#                             profile_path               credit_id.1  \
# count                             388618                    464314
# unique                             77370                    463836
# top     /akbW8jJl8GSXFpixFaobMOqvNv4.jpg  52fe4ac89251416c750edd47
# freq                                 241                         3
# mean                                 NaN                       NaN
# std                                  NaN                       NaN
# min                                  NaN                       NaN
# 25%                                  NaN                       NaN
# 50%                                  NaN                       NaN
# 75%                                  NaN                       NaN
# max                                  NaN                       NaN
#
#         department       gender.1        id_job       job        name_job  \
# count       464314  464314.000000  5.648920e+05    464314          464314
# unique          12            NaN           NaN       456          157614
# top     Production            NaN           NaN  Director  Cedric Gibbons
# freq         94498            NaN           NaN     49048             272
# mean           NaN       0.759975  5.306552e+05       NaN             NaN
# std            NaN       0.935607  6.634090e+05       NaN             NaN
# min            NaN       0.000000  0.000000e+00       NaN             NaN
# 25%            NaN       0.000000  6.510000e+03       NaN             NaN
# 50%            NaN       0.000000  7.104700e+04       NaN             NaN
# 75%            NaN       2.000000  1.304287e+06       NaN             NaN
# max            NaN       2.000000  1.908001e+06       NaN             NaN
#
#                           profile_path.1
# count                              95098
# unique                             13347
# top     /w8tc9iVH87Iu1KKFDZ9B99NhnBc.jpg
# freq                                 272
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para visualizar datos
def visualize_data(df, title):
    plt.figure(figsize=(14, 10))
    
    # Histograma de todas las columnas numéricas
    df.select_dtypes(include=['number']).hist(figsize=(14, 10), bins=30)
    plt.suptitle(f'Histograms for {title}')
    plt.show()

    # Boxplots para todas las columnas numéricas
    for col in df.select_dtypes(include=['number']).columns:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
        plt.show()

# Visualizar cada dataset
visualize_data(combined_df, 'Combined Dataset')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para visualizar datos
def visualize_data(df, title):
    plt.figure(figsize=(14, 10))
    
    # Histograma de todas las columnas numéricas
    df.select_dtypes(include=['number']).hist(figsize=(14, 10), bins=30)
    plt.suptitle(f'Histograms for {title}')
    plt.show()

    # Boxplots para todas las columnas numéricas
    for col in df.select_dtypes(include=['number']).columns:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
        plt.show()

# Visualizar cada dataset
visualize_data(movie_df, 'Movie Dataset Cleaned')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para visualizar datos
def visualize_data(df, title):
    plt.figure(figsize=(14, 10))
    
    # Histograma de todas las columnas numéricas
    df.select_dtypes(include=['number']).hist(figsize=(14, 10), bins=30)
    plt.suptitle(f'Histograms for {title}')
    plt.show()

    # Boxplots para todas las columnas numéricas
    for col in df.select_dtypes(include=['number']).columns:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
        plt.show()

# Visualizar cada dataset
visualize_data(df_unido_df, 'DF Unido')

# %%
# Boxplot para detectar outliers en las columnas numéricas
def detect_outliers(df, title):
    plt.figure(figsize=(14, 10))
    for i, col in enumerate(df.select_dtypes(include=['number']).columns):
        plt.subplot(len(df.select_dtypes(include=['number']).columns), 1, i + 1)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
    plt.tight_layout()
    plt.show()

detect_outliers(combined_df, 'Combined Dataset')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\884922648.py:8: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Boxplot para detectar outliers en las columnas numéricas
def detect_outliers(df, title):
    plt.figure(figsize=(14, 10))
    for i, col in enumerate(df.select_dtypes(include=['number']).columns):
        plt.subplot(len(df.select_dtypes(include=['number']).columns), 1, i + 1)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
    plt.tight_layout()
    plt.show()

detect_outliers(movie_df, 'Movie Dataset Cleaned')

# %%
# Boxplot para detectar outliers en las columnas numéricas
def detect_outliers(df, title):
    plt.figure(figsize=(14, 10))
    for i, col in enumerate(df.select_dtypes(include=['number']).columns):
        plt.subplot(len(df.select_dtypes(include=['number']).columns), 1, i + 1)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
    plt.tight_layout()
    plt.show()

detect_outliers(df_unido_df, 'DF Unido')

# %%
# %pip install wordcloud

from wordcloud import WordCloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar y procesar el dataset movie_df
movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
text_columns_movie = ['title', 'overview', 'genres', 'tagline']

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in movie_df.columns:
        movie_df[col] = movie_df[col].apply(preprocess_text)
        
# Cargar y procesar el dataset df_unido_df
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
text_columns_unido = ['title', 'overview', 'genres', 'tagline']

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_unido:
    if col in df_unido_df.columns:
        df_unido_df[col] = df_unido_df[col].apply(preprocess_text)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\622989332.py:13: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\622989332.py:22: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# %%
# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            all_texts[col] = ' '.join(df[col].dropna().astype(str))
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para movie_df
combined_text_movie = get_combined_text(movie_df, text_columns_movie)

# Obtener el texto combinado para df_unido_df
combined_text_unido = get_combined_text(df_unido_df, text_columns_unido)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset movie_df
movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')

# Columnas de texto relevantes
text_columns_movie = ['title', 'overview', 'genres', 'tagline']

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in movie_df.columns:
        movie_df[col] = movie_df[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para movie_df
combined_text_movie = get_combined_text(movie_df, text_columns_movie)
print("Texto combinado para movie_df:", combined_text_movie[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir
stopwords = set(STOPWORDS).union({'id', 'movie', 'film', 'data', 'name'})  # Puedes agregar más palabras aquí

# Función para generar y mostrar la nube de palabras
def generate_wordcloud(text, title, stopwords):
    if text.strip():  # Verificar que el texto no esté vacío
        wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(title)
        plt.show()
    else:
        print(f'No se puede generar la nube de palabras para {title} porque el texto está vacío.')

# Mostrar la nube de palabras para movie_df
generate_wordcloud(combined_text_movie, 'Nube de Palabras para Movie Dataset', stopwords)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\337835608.py:15: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# Texto combinado para movie_df: led by woody andys toys live happily in his room until andys birthday brings buzz lightyear onto the scene afraid of losing his place in andys heart woody plots against buzz but when circumstances separate buzz and woody from their owner the duo eventually learns to put aside their differences when siblings judy and peter discover an enchanted board game that opens the door to a magical world they unwittingly invite alan  an adult whos been trapped inside the game for 26 years  into their living

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset df_unido_df
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# Columnas de texto relevantes (revisar y ajustar según el contenido)
text_columns_unido = ['character', 'name', 'department', 'job']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_unido:
    if col in df_unido_df.columns:
        df_unido_df[col] = df_unido_df[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_unido_df
combined_text_unido = get_combined_text(df_unido_df, text_columns_unido)
print("Texto combinado para df_unido_df (primeros 500 caracteres):", combined_text_unido[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir
stopwords = set(STOPWORDS).union({'id', 'name', 'character', 'department', 'job'})  # Puedes agregar más palabras aquí

# Función para generar y mostrar la nube de palabras
def generate_wordcloud(text, title, stopwords):
    if text.strip():  # Verificar que el texto no esté vacío
        wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(title)
        plt.show()
    else:
        print(f'No se puede generar la nube de palabras para {title} porque el texto está vacío.')

# Mostrar la nube de palabras para df_unido_df
generate_wordcloud(combined_text_unido, 'Nube de Palabras para DF Unido Dataset', stopwords)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\2510537884.py:15: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
# Texto combinado para df_unido_df (primeros 500 caracteres): woody voice buzz lightyear voice mr potato head voice slinky dog voice rex voice hamm voice bo peep voice andy voice sid voice mrs davis voice sergeant voice hannah voice tv announcer voice alan parrish samuel alan parrish  van pelt judy sheperd peter shepherd sarah whittle nora shepherd carl bentley carol anne parrish alan parrish young sarah whittle young exterminator mrs thomas the realtor benjamin caleb billy jessup cop bum jim shepherd martha shepherd gun salesman paramedic paramedic girl g

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset df_unido_df
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# Columnas de texto relevantes (revisar y ajustar según el contenido)
text_columns_unido = ['character', 'name', 'department', 'job']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_unido:
    if col in df_unido_df.columns:
        df_unido_df[col] = df_unido_df[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_unido_df
combined_text_unido = get_combined_text(df_unido_df, text_columns_unido)
print("Texto combinado para df_unido_df (primeros 500 caracteres):", combined_text_unido[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir (stopwords)
stopwords = {'id', 'name', 'character', 'department', 'job'}  # Puedes agregar más palabras aquí

# Función para contar palabras y realizar estadísticas
def analyze_word_frequencies(text, stopwords, top_n=20):
    words = text.split()
    # Filtrar las stopwords
    filtered_words = [word for word in words if word not in stopwords]
    word_counts = Counter(filtered_words)

    # Estadísticas básicas
    total_words = len(filtered_words)
    unique_words = len(word_counts)
    most_common_word, most_common_count = word_counts.most_common(1)[0]

    # Imprimir estadísticas
    print(f"Total de palabras: {total_words}")
    print(f"Número de palabras únicas: {unique_words}")
    print(f"Palabra más frecuente: '{most_common_word}' (Frecuencia: {most_common_count})")

    # Obtener las 'top_n' palabras más frecuentes
    most_common_words = word_counts.most_common(top_n)

    # Separar las palabras y las frecuencias para graficar
    words, counts = zip(*most_common_words)

    # Graficar las palabras más frecuentes
    plt.figure(figsize=(10, 5))
    plt.bar(words, counts, color='skyblue')
    plt.xlabel('Palabras')
    plt.ylabel('Frecuencia')
    plt.title(f'Top {top_n} Palabras Más Frecuentes')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Mostrar el análisis de frecuencia de palabras y estadísticas básicas
analyze_word_frequencies(combined_text_unido, stopwords, top_n=20)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\456273356.py:15: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
# Texto combinado para df_unido_df (primeros 500 caracteres): woody voice buzz lightyear voice mr potato head voice slinky dog voice rex voice hamm voice bo peep voice andy voice sid voice mrs davis voice sergeant voice hannah voice tv announcer voice alan parrish samuel alan parrish  van pelt judy sheperd peter shepherd sarah whittle nora shepherd carl bentley carol anne parrish alan parrish young sarah whittle young exterminator mrs thomas the realtor benjamin caleb billy jessup cop bum jim shepherd martha shepherd gun salesman paramedic paramedic girl g
# Total de palabras: 2295847
# Número de palabras únicas: 128329
# Palabra más frecuente: 'production' (Frecuencia: 113832)

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset movie_dataset_cleaned
df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')

# Columnas de texto relevantes (ajustar según las columnas de texto del dataset)
text_columns_movie = ['title', 'overview', 'tagline', 'genres', 'keywords']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in df_movie.columns:
        df_movie[col] = df_movie[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_movie
combined_text_movie = get_combined_text(df_movie, text_columns_movie)
print("Texto combinado para df_movie (primeros 500 caracteres):", combined_text_movie[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir (stopwords)
stopwords = {'id', 'title', 'overview', 'tagline', 'genres', 'keywords'}  # Puedes agregar más palabras aquí

# Función para contar palabras y realizar estadísticas
def analyze_word_frequencies(text, stopwords, top_n=20):
    words = text.split()
    # Filtrar las stopwords
    filtered_words = [word for word in words if word not in stopwords]
    word_counts = Counter(filtered_words)

    # Estadísticas básicas
    total_words = len(filtered_words)
    unique_words = len(word_counts)
    most_common_word, most_common_count = word_counts.most_common(1)[0]

    # Imprimir estadísticas
    print(f"Total de palabras: {total_words}")
    print(f"Número de palabras únicas: {unique_words}")
    print(f"Palabra más frecuente: '{most_common_word}' (Frecuencia: {most_common_count})")

    # Obtener las 'top_n' palabras más frecuentes
    most_common_words = word_counts.most_common(top_n)

    # Separar las palabras y las frecuencias para graficar
    words, counts = zip(*most_common_words)

    # Graficar las palabras más frecuentes
    plt.figure(figsize=(10, 5))
    plt.bar(words, counts, color='skyblue')
    plt.xlabel('Palabras')
    plt.ylabel('Frecuencia')
    plt.title(f'Top {top_n} Palabras Más Frecuentes')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Mostrar el análisis de frecuencia de palabras y estadísticas básicas
analyze_word_frequencies(combined_text_movie, stopwords, top_n=20)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\2186902424.py:15: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# Texto combinado para df_movie (primeros 500 caracteres): led by woody andys toys live happily in his room until andys birthday brings buzz lightyear onto the scene afraid of losing his place in andys heart woody plots against buzz but when circumstances separate buzz and woody from their owner the duo eventually learns to put aside their differences when siblings judy and peter discover an enchanted board game that opens the door to a magical world they unwittingly invite alan  an adult whos been trapped inside the game for 26 years  into their living
# Total de palabras: 2618935
# Número de palabras únicas: 94374
# Palabra más frecuente: 'the' (Frecuencia: 149479)

# %%
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter
import nltk
from nltk.corpus import stopwords

# Descargar las stopwords de nltk
nltk.download('stopwords')

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset movie_dataset_cleaned
df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')

# Columnas de texto relevantes (ajustar según las columnas de texto del dataset)
text_columns_movie = ['title', 'overview', 'tagline', 'genres', 'keywords']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in df_movie.columns:
        df_movie[col] = df_movie[col].apply(preprocess_text)

# Obtener el conjunto de stopwords en inglés de nltk
stopwords_nltk = set(stopwords.words('english'))

# Añadir más stopwords específicas del dataset si es necesario
custom_stopwords = {'id', 'title', 'overview', 'tagline', 'genres', 'keywords'}

# Combinar las stopwords de nltk con las personalizadas
all_stopwords = stopwords_nltk.union(custom_stopwords)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_movie
combined_text_movie = get_combined_text(df_movie, text_columns_movie)
print("Texto combinado para df_movie (primeros 500 caracteres):", combined_text_movie[:500])  # Mostrar los primeros 500 caracteres

# Función para contar palabras y realizar estadísticas
def analyze_word_frequencies(text, stopwords, top_n=20):
    words = text.split()
    # Filtrar las stopwords
    filtered_words = [word for word in words if word not in stopwords]
    word_counts = Counter(filtered_words)

    # Estadísticas básicas
    total_words = len(filtered_words)
    unique_words = len(word_counts)
    most_common_word, most_common_count = word_counts.most_common(1)[0]

    # Imprimir estadísticas
    print(f"Total de palabras: {total_words}")
    print(f"Número de palabras únicas: {unique_words}")
    print(f"Palabra más frecuente: '{most_common_word}' (Frecuencia: {most_common_count})")

    # Obtener las 'top_n' palabras más frecuentes
    most_common_words = word_counts.most_common(top_n)

    # Separar las palabras y las frecuencias para graficar
    words, counts = zip(*most_common_words)

    # Graficar las palabras más frecuentes
    plt.figure(figsize=(10, 5))
    plt.bar(words, counts, color='skyblue')
    plt.xlabel('Palabras')
    plt.ylabel('Frecuencia')
    plt.title(f'Top {top_n} Palabras Más Frecuentes')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Mostrar el análisis de frecuencia de palabras y estadísticas básicas
analyze_word_frequencies(combined_text_movie, all_stopwords, top_n=20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8128\2804604556.py:20: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# Texto combinado para df_movie (primeros 500 caracteres): led by woody andys toys live happily in his room until andys birthday brings buzz lightyear onto the scene afraid of losing his place in andys heart woody plots against buzz but when circumstances separate buzz and woody from their owner the duo eventually learns to put aside their differences when siblings judy and peter discover an enchanted board game that opens the door to a magical world they unwittingly invite alan  an adult whos been trapped inside the game for 26 years  into their living
# Total de palabras: 1501324
# Número de palabras únicas: 94234
# Palabra más frecuente: 'one' (Frecuencia: 8576)
