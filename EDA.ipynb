# %%
import pandas as pd

# Cargar el dataset combinado
combined_df = pd.read_csv('D:/SOYHENRY_PI_1/combined_dataset.csv')

# Cargar los datasets individuales (suponiendo que también están en formato CSV)
movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\859282774.py:4: DtypeWarning: Columns (0,9,10,13,14,15,17,18,19,20,21,22,23,26,27,28,29,33,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_df = pd.read_csv('D:/SOYHENRY_PI_1/combined_dataset.csv')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\859282774.py:7: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\859282774.py:8: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# %%
# Revisión de los primeros datos
print("Combined Dataset:")
print(combined_df.head())
# Out:
# Combined Dataset:
#         id  cast_id character                 credit_id  gender     id.1  \
# 0    100.0      NaN       NaN                       NaN     NaN      NaN
# 1    100.0     19.0     Morag  588c3935c3a368131b001479     1.0   1834.0
# 2  10000.0      NaN       NaN                       NaN     NaN      NaN
# 3  10000.0      5.0   Bledsoe  52fe43a99251416c750192cf     2.0  66813.0
# 4  10001.0      NaN       NaN                       NaN     NaN      NaN
#
#                 name  order                      profile_path  \
# 0                NaN    NaN                               NaN
# 1  Shirley Henderson    8.0  /yxFCumQ2vjMgpdENmroOFN6KENO.jpg
# 2                NaN    NaN                               NaN
# 3     Robert Swenson    3.0  /cNuq7a8nCxRw9pNvQVVQoONkNsw.jpg
# 4                NaN    NaN                               NaN
#
#                 credit_id.1  ... vote_average  vote_count  collection_id  \
# ...

# %%
# Información de los DataFrames
print("\nCombined Dataset Info:")
print(combined_df.info())
# Out:
# Combined Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610358 entries, 0 to 610357
# Data columns (total 40 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    90942 non-null   object
#  1   cast_id               562474 non-null  float64
#  2   character             536691 non-null  object
#  3   credit_id             562474 non-null  object
#  4   gender                562474 non-null  float64
#  5   id.1                  562474 non-null  float64
#  6   name                  562474 non-null  object
#  7   order                 562474 non-null  float64
#  8   profile_path          388618 non-null  object
#  9   credit_id.1           464314 non-null  object
#  10  department            464314 non-null  object
#  11  gender.1              464314 non-null  float64
#  12  id.2                  464314 non-null  float64
#  13  job                   464314 non-null  object
# ...

# %%
# Estadísticas descriptivas
print("Combined Dataset Description:")
print(combined_df.describe(include='all'))
# Out:
# Combined Dataset Description:
#               id        cast_id character                 credit_id  \
# count    90942.0  562474.000000    536691                    562474
# unique   53620.0            NaN    319326                    562044
# top     141971.0            NaN   Himself  52fe4ac89251416c750edd25
# freq         6.0            NaN     11437                         3
# mean         NaN      51.563372       NaN                       NaN
# std          NaN     172.998891       NaN                       NaN
# min          NaN       0.000000       NaN                       NaN
# 25%          NaN       6.000000       NaN                       NaN
# 50%          NaN      13.000000       NaN                       NaN
# 75%          NaN      27.000000       NaN                       NaN
# max          NaN    1119.000000       NaN                       NaN
#
#                gender          id.1          name          order  \
# ...

# %%
# Revisión de los primeros datos
print("\nMovie Dataset Cleaned:")
print(movie_df.head())
# Out:
# Movie Dataset Cleaned:
#        budget                                             genres     id  \
# 0  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0.0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
# 3                en  Cheated on, mistreated and stepped on, the wom...
# 4                en  Just when George Banks has recovered from his ...
#
#   popularity                               production_companies  \
# ...

# %%
# Información de los DataFrames
print("\nMovie Dataset Cleaned Info:")
print(movie_df.info())
# Out:
# Movie Dataset Cleaned Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                45466 non-null  float64
#  1   genres                45466 non-null  object
#  2   id                    45466 non-null  object
#  3   original_language     45455 non-null  object
#  4   overview              44512 non-null  object
#  5   popularity            45461 non-null  object
#  6   production_companies  45463 non-null  object
#  7   production_countries  45463 non-null  object
#  8   release_date          45466 non-null  object
#  9   revenue               45460 non-null  float64
#  10  runtime               45203 non-null  float64
#  11  spoken_languages      45460 non-null  object
#  12  status                45379 non-null  object
#  13  tagline               20412 non-null  object
# ...

# %%
# Estadísticas descriptivas
print("\nMovie Dataset Cleaned Description:")
print(movie_df.describe(include='all'))
# Out:
# Movie Dataset Cleaned Description:
#               budget                         genres      id original_language  \
# count   4.546600e+04                          45466   45466             45455
# unique           NaN                           4069   45436                92
# top              NaN  [{'id': 18, 'name': 'Drama'}]  141971                en
# freq             NaN                           5000       3             32269
# mean    4.224300e+06                            NaN     NaN               NaN
# std     1.742359e+07                            NaN     NaN               NaN
# min     0.000000e+00                            NaN     NaN               NaN
# 25%     0.000000e+00                            NaN     NaN               NaN
# 50%     0.000000e+00                            NaN     NaN               NaN
# 75%     0.000000e+00                            NaN     NaN               NaN
# max     3.800000e+08                            NaN     NaN               NaN
# ...

# %%
# Revisión de los primeros datos
print("\nDF Unido:")
print(df_unido_df.head())
# Out:
# DF Unido:
#         id  cast_id                character                 credit_id  \
# 0    862.0     14.0            Woody (voice)  52fe4284c3a36847f8024f95
# 1   8844.0     15.0   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 2  15602.0     16.0  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 3  31357.0     17.0       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 4  11862.0     18.0              Rex (voice)  52fe4284c3a36847f8024fa5
#
#    gender     id.1           name  order                      profile_path  \
# 0     2.0     31.0      Tom Hanks    0.0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1     2.0  12898.0      Tim Allen    1.0  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2     2.0   7167.0    Don Rickles    2.0  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3     2.0  12899.0     Jim Varney    3.0  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4     2.0  12900.0  Wallace Shawn    4.0  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg
#
#                 credit_id.1 department  gender.1     id.2         job  \
# ...

# %%
# Información de los DataFrames
print("\nDF Unido Info:")
print(df_unido_df.info())
# Out:
# DF Unido Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564892 entries, 0 to 564891
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              45476 non-null   float64
#  1   cast_id         562474 non-null  float64
#  2   character       536691 non-null  object
#  3   credit_id       562474 non-null  object
#  4   gender          562474 non-null  float64
#  5   id.1            562474 non-null  float64
#  6   name            562474 non-null  object
#  7   order           562474 non-null  float64
#  8   profile_path    388618 non-null  object
#  9   credit_id.1     464314 non-null  object
#  10  department      464314 non-null  object
#  11  gender.1        464314 non-null  float64
#  12  id.2            464314 non-null  float64
#  13  job             464314 non-null  object
#  14  name.1          464314 non-null  object
#  15  profile_path.1  95098 non-null   object
# ...

# %%
# Estadísticas descriptivas
print("\nDF Unido Description:")
print(df_unido_df.describe(include='all'))
# Out:
# DF Unido Description:
#                    id        cast_id character                 credit_id  \
# count    45476.000000  562474.000000    536691                    562474
# unique            NaN            NaN    319326                    562044
# top               NaN            NaN   Himself  52fe4ac89251416c750edd31
# freq              NaN            NaN     11437                         3
# mean    108345.997537      51.563372       NaN                       NaN
# std     112443.796536     172.998891       NaN                       NaN
# min          2.000000       0.000000       NaN                       NaN
# 25%      26443.250000       6.000000       NaN                       NaN
# 50%      60002.500000      13.000000       NaN                       NaN
# 75%     157302.000000      27.000000       NaN                       NaN
# max     469172.000000    1119.000000       NaN                       NaN
#
#                gender          id.1          name          order  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para visualizar datos
def visualize_data(df, title):
    plt.figure(figsize=(14, 10))
    
    # Histograma de todas las columnas numéricas
    df.select_dtypes(include=['number']).hist(figsize=(14, 10), bins=30)
    plt.suptitle(f'Histograms for {title}')
    plt.show()

    # Boxplots para todas las columnas numéricas
    for col in df.select_dtypes(include=['number']).columns:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
        plt.show()

# Visualizar cada dataset
visualize_data(combined_df, 'Combined Dataset')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para visualizar datos
def visualize_data(df, title):
    plt.figure(figsize=(14, 10))
    
    # Histograma de todas las columnas numéricas
    df.select_dtypes(include=['number']).hist(figsize=(14, 10), bins=30)
    plt.suptitle(f'Histograms for {title}')
    plt.show()

    # Boxplots para todas las columnas numéricas
    for col in df.select_dtypes(include=['number']).columns:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
        plt.show()

# Visualizar cada dataset
visualize_data(movie_df, 'Movie Dataset Cleaned')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para visualizar datos
def visualize_data(df, title):
    plt.figure(figsize=(14, 10))
    
    # Histograma de todas las columnas numéricas
    df.select_dtypes(include=['number']).hist(figsize=(14, 10), bins=30)
    plt.suptitle(f'Histograms for {title}')
    plt.show()

    # Boxplots para todas las columnas numéricas
    for col in df.select_dtypes(include=['number']).columns:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
        plt.show()

# Visualizar cada dataset
visualize_data(df_unido_df, 'DF Unido')

# %%
# Boxplot para detectar outliers en las columnas numéricas
def detect_outliers(df, title):
    plt.figure(figsize=(14, 10))
    for i, col in enumerate(df.select_dtypes(include=['number']).columns):
        plt.subplot(len(df.select_dtypes(include=['number']).columns), 1, i + 1)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
    plt.tight_layout()
    plt.show()

detect_outliers(combined_df, 'Combined Dataset')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\884922648.py:8: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Boxplot para detectar outliers en las columnas numéricas
def detect_outliers(df, title):
    plt.figure(figsize=(14, 10))
    for i, col in enumerate(df.select_dtypes(include=['number']).columns):
        plt.subplot(len(df.select_dtypes(include=['number']).columns), 1, i + 1)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
    plt.tight_layout()
    plt.show()

detect_outliers(movie_df, 'Movie Dataset Cleaned')

# %%
# Boxplot para detectar outliers en las columnas numéricas
def detect_outliers(df, title):
    plt.figure(figsize=(14, 10))
    for i, col in enumerate(df.select_dtypes(include=['number']).columns):
        plt.subplot(len(df.select_dtypes(include=['number']).columns), 1, i + 1)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col} in {title}')
    plt.tight_layout()
    plt.show()

detect_outliers(df_unido_df, 'DF Unido')

# %%
print(df.columns)
# Out:
# Index(['id', 'cast_id', 'character', 'credit_id', 'gender', 'id.1', 'name',
#        'order', 'profile_path', 'credit_id.1', 'department', 'gender.1',
#        'id.2', 'job', 'name.1', 'profile_path.1', 'budget', 'genres',
#        'original_language', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'collection_id', 'collection_name', 'collection_poster',
#        'collection_backdrop', 'company_names', 'company_ids', 'release_year',
#        'return'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt

# Cargar el dataset
df = pd.read_csv('D:/SOYHENRY_PI_1/combined_dataset.csv')

# Seleccionar columnas de texto relevantes
text_columns = ['title', 'overview', 'genres', 'tagline']

# Concatenar todos los textos en uno solo para cada columna
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Procesar y concatenar texto de cada columna
all_texts = {}
for col in text_columns:
    df[col] = df[col].apply(preprocess_text)
    all_texts[col] = ' '.join(df[col].dropna().astype(str))

# Unir todos los textos en uno solo
combined_text = ' '.join(all_texts.values())
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\3982408850.py:8: DtypeWarning: Columns (0,9,10,13,14,15,17,18,19,20,21,22,23,26,27,28,29,33,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:/SOYHENRY_PI_1/combined_dataset.csv')

# %%
# !pip install wordcloud

from wordcloud import WordCloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import re

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar y procesar el dataset movie_df
movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
text_columns_movie = ['title', 'overview', 'genres', 'tagline']

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in movie_df.columns:
        movie_df[col] = movie_df[col].apply(preprocess_text)
        
# Cargar y procesar el dataset df_unido_df
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
text_columns_unido = ['title', 'overview', 'genres', 'tagline']

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_unido:
    if col in df_unido_df.columns:
        df_unido_df[col] = df_unido_df[col].apply(preprocess_text)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\622989332.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\622989332.py:22: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# %%
# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            all_texts[col] = ' '.join(df[col].dropna().astype(str))
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para movie_df
combined_text_movie = get_combined_text(movie_df, text_columns_movie)

# Obtener el texto combinado para df_unido_df
combined_text_unido = get_combined_text(df_unido_df, text_columns_unido)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset movie_df
movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')

# Columnas de texto relevantes
text_columns_movie = ['title', 'overview', 'genres', 'tagline']

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in movie_df.columns:
        movie_df[col] = movie_df[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para movie_df
combined_text_movie = get_combined_text(movie_df, text_columns_movie)
print("Texto combinado para movie_df:", combined_text_movie[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir
stopwords = set(STOPWORDS).union({'id', 'movie', 'film', 'data', 'name'})  # Puedes agregar más palabras aquí

# Función para generar y mostrar la nube de palabras
def generate_wordcloud(text, title, stopwords):
    if text.strip():  # Verificar que el texto no esté vacío
        wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(title)
        plt.show()
    else:
        print(f'No se puede generar la nube de palabras para {title} porque el texto está vacío.')

# Mostrar la nube de palabras para movie_df
generate_wordcloud(combined_text_movie, 'Nube de Palabras para Movie Dataset', stopwords)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\337835608.py:15: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# Texto combinado para movie_df: toy story jumanji grumpier old men waiting to exhale father of the bride part ii heat sabrina tom and huck sudden death goldeneye the american president dracula dead and loving it balto nixon cutthroat island casino sense and sensibility four rooms ace ventura when nature calls money train get shorty copycat assassins powder leaving las vegas othello now and then persuasion the city of lost children shanghai triad dangerous minds twelve monkeys wings of courage babe carrington dead man walking a

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset df_unido_df
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# Columnas de texto relevantes (revisar y ajustar según el contenido)
text_columns_unido = ['character', 'name', 'department', 'job']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_unido:
    if col in df_unido_df.columns:
        df_unido_df[col] = df_unido_df[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_unido_df
combined_text_unido = get_combined_text(df_unido_df, text_columns_unido)
print("Texto combinado para df_unido_df (primeros 500 caracteres):", combined_text_unido[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir
stopwords = set(STOPWORDS).union({'id', 'name', 'character', 'department', 'job'})  # Puedes agregar más palabras aquí

# Función para generar y mostrar la nube de palabras
def generate_wordcloud(text, title, stopwords):
    if text.strip():  # Verificar que el texto no esté vacío
        wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(title)
        plt.show()
    else:
        print(f'No se puede generar la nube de palabras para {title} porque el texto está vacío.')

# Mostrar la nube de palabras para df_unido_df
generate_wordcloud(combined_text_unido, 'Nube de Palabras para DF Unido Dataset', stopwords)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\2510537884.py:15: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
# Texto combinado para df_unido_df (primeros 500 caracteres): woody voice buzz lightyear voice mr potato head voice slinky dog voice rex voice hamm voice bo peep voice andy voice sid voice mrs davis voice sergeant voice hannah voice tv announcer voice alan parrish samuel alan parrish  van pelt judy sheperd peter shepherd sarah whittle nora shepherd carl bentley carol anne parrish alan parrish young sarah whittle young exterminator mrs thomas the realtor benjamin caleb billy jessup cop bum jim shepherd martha shepherd gun salesman paramedic paramedic girl g

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset df_unido_df
df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')

# Columnas de texto relevantes (revisar y ajustar según el contenido)
text_columns_unido = ['character', 'name', 'department', 'job']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_unido:
    if col in df_unido_df.columns:
        df_unido_df[col] = df_unido_df[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_unido_df
combined_text_unido = get_combined_text(df_unido_df, text_columns_unido)
print("Texto combinado para df_unido_df (primeros 500 caracteres):", combined_text_unido[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir (stopwords)
stopwords = {'id', 'name', 'character', 'department', 'job'}  # Puedes agregar más palabras aquí

# Función para contar palabras y realizar estadísticas
def analyze_word_frequencies(text, stopwords, top_n=20):
    words = text.split()
    # Filtrar las stopwords
    filtered_words = [word for word in words if word not in stopwords]
    word_counts = Counter(filtered_words)

    # Estadísticas básicas
    total_words = len(filtered_words)
    unique_words = len(word_counts)
    most_common_word, most_common_count = word_counts.most_common(1)[0]

    # Imprimir estadísticas
    print(f"Total de palabras: {total_words}")
    print(f"Número de palabras únicas: {unique_words}")
    print(f"Palabra más frecuente: '{most_common_word}' (Frecuencia: {most_common_count})")

    # Obtener las 'top_n' palabras más frecuentes
    most_common_words = word_counts.most_common(top_n)

    # Separar las palabras y las frecuencias para graficar
    words, counts = zip(*most_common_words)

    # Graficar las palabras más frecuentes
    plt.figure(figsize=(10, 5))
    plt.bar(words, counts, color='skyblue')
    plt.xlabel('Palabras')
    plt.ylabel('Frecuencia')
    plt.title(f'Top {top_n} Palabras Más Frecuentes')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Mostrar el análisis de frecuencia de palabras y estadísticas básicas
analyze_word_frequencies(combined_text_unido, stopwords, top_n=20)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\456273356.py:15: DtypeWarning: Columns (9,10,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_unido_df = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/df_unido.csv')
# Texto combinado para df_unido_df (primeros 500 caracteres): woody voice buzz lightyear voice mr potato head voice slinky dog voice rex voice hamm voice bo peep voice andy voice sid voice mrs davis voice sergeant voice hannah voice tv announcer voice alan parrish samuel alan parrish  van pelt judy sheperd peter shepherd sarah whittle nora shepherd carl bentley carol anne parrish alan parrish young sarah whittle young exterminator mrs thomas the realtor benjamin caleb billy jessup cop bum jim shepherd martha shepherd gun salesman paramedic paramedic girl g
# Total de palabras: 3461068
# Número de palabras únicas: 204866
# Palabra más frecuente: 'production' (Frecuencia: 113832)

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset movie_dataset_cleaned
df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')

# Columnas de texto relevantes (ajustar según las columnas de texto del dataset)
text_columns_movie = ['title', 'overview', 'tagline', 'genres', 'keywords']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in df_movie.columns:
        df_movie[col] = df_movie[col].apply(preprocess_text)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_movie
combined_text_movie = get_combined_text(df_movie, text_columns_movie)
print("Texto combinado para df_movie (primeros 500 caracteres):", combined_text_movie[:500])  # Mostrar los primeros 500 caracteres

# Lista de palabras a excluir (stopwords)
stopwords = {'id', 'title', 'overview', 'tagline', 'genres', 'keywords'}  # Puedes agregar más palabras aquí

# Función para contar palabras y realizar estadísticas
def analyze_word_frequencies(text, stopwords, top_n=20):
    words = text.split()
    # Filtrar las stopwords
    filtered_words = [word for word in words if word not in stopwords]
    word_counts = Counter(filtered_words)

    # Estadísticas básicas
    total_words = len(filtered_words)
    unique_words = len(word_counts)
    most_common_word, most_common_count = word_counts.most_common(1)[0]

    # Imprimir estadísticas
    print(f"Total de palabras: {total_words}")
    print(f"Número de palabras únicas: {unique_words}")
    print(f"Palabra más frecuente: '{most_common_word}' (Frecuencia: {most_common_count})")

    # Obtener las 'top_n' palabras más frecuentes
    most_common_words = word_counts.most_common(top_n)

    # Separar las palabras y las frecuencias para graficar
    words, counts = zip(*most_common_words)

    # Graficar las palabras más frecuentes
    plt.figure(figsize=(10, 5))
    plt.bar(words, counts, color='skyblue')
    plt.xlabel('Palabras')
    plt.ylabel('Frecuencia')
    plt.title(f'Top {top_n} Palabras Más Frecuentes')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Mostrar el análisis de frecuencia de palabras y estadísticas básicas
analyze_word_frequencies(combined_text_movie, stopwords, top_n=20)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\2186902424.py:15: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# Texto combinado para df_movie (primeros 500 caracteres): toy story jumanji grumpier old men waiting to exhale father of the bride part ii heat sabrina tom and huck sudden death goldeneye the american president dracula dead and loving it balto nixon cutthroat island casino sense and sensibility four rooms ace ventura when nature calls money train get shorty copycat assassins powder leaving las vegas othello now and then persuasion the city of lost children shanghai triad dangerous minds twelve monkeys wings of courage babe carrington dead man walking a
# Total de palabras: 3031768
# Número de palabras únicas: 100063
# Palabra más frecuente: 'the' (Frecuencia: 164051)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter
import nltk
from nltk.corpus import stopwords

# Descargar las stopwords de nltk
nltk.download('stopwords')

# Función para preprocesar el texto
def preprocess_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación
    return text

# Cargar el dataset movie_dataset_cleaned
df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')

# Columnas de texto relevantes (ajustar según las columnas de texto del dataset)
text_columns_movie = ['title', 'overview', 'tagline', 'genres', 'keywords']  # Ajusta si es necesario

# Aplicar preprocesamiento a cada columna de texto
for col in text_columns_movie:
    if col in df_movie.columns:
        df_movie[col] = df_movie[col].apply(preprocess_text)

# Obtener el conjunto de stopwords en inglés de nltk
stopwords_nltk = set(stopwords.words('english'))

# Añadir más stopwords específicas del dataset si es necesario
custom_stopwords = {'id', 'title', 'overview', 'tagline', 'genres', 'keywords'}

# Combinar las stopwords de nltk con las personalizadas
all_stopwords = stopwords_nltk.union(custom_stopwords)

# Función para obtener texto combinado
def get_combined_text(df, columns):
    all_texts = {}
    for col in columns:
        if col in df.columns:
            text = ' '.join(df[col].dropna().astype(str))
            if text:
                all_texts[col] = text
            else:
                print(f'No text found in column: {col}')
    combined_text = ' '.join(all_texts.values())
    return combined_text

# Obtener el texto combinado para df_movie
combined_text_movie = get_combined_text(df_movie, text_columns_movie)
print("Texto combinado para df_movie (primeros 500 caracteres):", combined_text_movie[:500])  # Mostrar los primeros 500 caracteres

# Función para contar palabras y realizar estadísticas
def analyze_word_frequencies(text, stopwords, top_n=20):
    words = text.split()
    # Filtrar las stopwords
    filtered_words = [word for word in words if word not in stopwords]
    word_counts = Counter(filtered_words)

    # Estadísticas básicas
    total_words = len(filtered_words)
    unique_words = len(word_counts)
    most_common_word, most_common_count = word_counts.most_common(1)[0]

    # Imprimir estadísticas
    print(f"Total de palabras: {total_words}")
    print(f"Número de palabras únicas: {unique_words}")
    print(f"Palabra más frecuente: '{most_common_word}' (Frecuencia: {most_common_count})")

    # Obtener las 'top_n' palabras más frecuentes
    most_common_words = word_counts.most_common(top_n)

    # Separar las palabras y las frecuencias para graficar
    words, counts = zip(*most_common_words)

    # Graficar las palabras más frecuentes
    plt.figure(figsize=(10, 5))
    plt.bar(words, counts, color='skyblue')
    plt.xlabel('Palabras')
    plt.ylabel('Frecuencia')
    plt.title(f'Top {top_n} Palabras Más Frecuentes')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Mostrar el análisis de frecuencia de palabras y estadísticas básicas
analyze_word_frequencies(combined_text_movie, all_stopwords, top_n=20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15772\2804604556.py:20: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movie = pd.read_csv('D:/SOYHENRY_PI_1/fastapi_project/movie_dataset_cleaned.csv')
# Texto combinado para df_movie (primeros 500 caracteres): toy story jumanji grumpier old men waiting to exhale father of the bride part ii heat sabrina tom and huck sudden death goldeneye the american president dracula dead and loving it balto nixon cutthroat island casino sense and sensibility four rooms ace ventura when nature calls money train get shorty copycat assassins powder leaving las vegas othello now and then persuasion the city of lost children shanghai triad dangerous minds twelve monkeys wings of courage babe carrington dead man walking a
# ...
